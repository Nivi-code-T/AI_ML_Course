# %%
import pandas as pd

# %%
#2 main data types
series=pd.Series(["BMW","Toyota","Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
#series- 1 dimensional

# %%
colours=pd.Series(["Blue","Orange","Purple"])

# %%
colours
# Out:
# 0      Blue
# 1    Orange
# 2    Purple
# dtype: object

# %%
#DataFrame- 2 dimensional

# %%
car_colour=pd.DataFrame({"Car Makes":series,"Colour":colours})

# %%
car_colour
# Out:
#   Car Makes  Colour
# 0       BMW    Blue
# 1    Toyota  Orange
# 2     Honda  Purple

# %%
#import data
car_sales=pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#export csv
car_sales.to_csv("Export_car_sales.csv",index=False)

# %%
exported_cars=pd.read_csv("Export_car_sales.csv")
exported_cars
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe Data

# %%
#dtype is an Attribute
car_sales.dtypes

#to csv is Functions
#Export_car.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns=car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
#Indexes
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
#Functions
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
#info
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
#Avg of cars
car_price=pd.Series([1100,1200,1300,1400])
car_price.mean(numeric_only=True)
# Out:
# np.float64(1250.0)

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# np.int64(40)

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## Viewing and Selecting Data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.head(-1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 car_sales.head(-1)
#
# NameError: name 'car_sales' is not defined

# %%
car_sales.head(10)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
import pandas as pd
car_sales=pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals=pd.Series(["Dog","Panda","Monkey","Elephant"])

# %%
animals
# Out:
# 0         Dog
# 1       Panda
# 2      Monkey
# 3    Elephant
# dtype: object

# %%
animals.loc[:3]
# Out:
# 0         Dog
# 1       Panda
# 2      Monkey
# 3    Elephant
# dtype: object

# %%
animals.iloc[:3]
# Out:
# 0       Dog
# 1     Panda
# 2    Monkey
# dtype: object

# %%
s=pd.DataFrame({'s1':list('abcd'),'s2':list('efgh'),'s3':list('ijkl')},dtype='category')
print("categories=\n",s)
print("dtype=\n",s.dtypes)
# Out:
# categories=
#    s1 s2 s3
# 0  a  e  i
# 1  b  f  j
# 2  c  g  k
# 3  d  h  l
# dtype=
#  s1    category
# s2    category
# s3    category
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Doors"].plot()
# Out:
# <Axes: >

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Doors"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"].dtype
# Out:
# dtype('O')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Make"]=car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
car_sales=pd.read_csv("Export_car_sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White       150043.0    4.0   $4,000.00
# 1   Honda    Red        87899.0    4.0   $5,000.00
# 2  Toyota   Blue        32549.0    3.0   $7,000.00
# 3     BMW  Black        11179.0    5.0  $22,000.00
# 4  Nissan  White       213095.0    NaN   $3,500.00
# 5  Toyota    NaN        99213.0    4.0   $4,500.00
# 6   Honda   Blue        45698.0    4.0          NaN
# 7   Honda   Blue        54738.0    4.0   $7,000.00
# 8  Toyota  White            NaN    4.0   $6,250.00
# 9  Nissan  White        31600.0    4.0   $9,700.00

# %%
car_sales.sample(frac=0.5)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 5  Toyota   Blue        99213.0    4.0  $4,500.00
# 0  Toyota  White       150043.0    4.0  $4,000.00
# 6   Honda   Blue        45698.0    4.0         NaN
# 9  Nissan  White        31600.0    4.0  $9,700.00
# 4  Nissan  White       213095.0    NaN  $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White   58610.546875    4.0   $4,000.00
# 1   Honda    Red   34335.546875    4.0   $5,000.00
# 2  Toyota   Blue   12714.453125    3.0   $7,000.00
# 3     BMW  Black    4366.796875    5.0  $22,000.00
# 4  Nissan  White   83240.234375    NaN   $3,500.00
# 5  Toyota   Blue   38755.078125    4.0   $4,500.00
# 6   Honda   Blue   17850.781250    4.0          NaN
# 7   Honda   Blue   21382.031250    4.0   $7,000.00
# 8  Toyota  White   31511.024306    4.0   $6,250.00
# 9  Nissan  White   12343.750000    4.0   $9,700.00

# %%
car_sales["Odometer (KM)"]=car_sales["Odometer (KM)"].apply(lambda x: x / 1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White   58610.546875    4.0   $4,000.00
# 1   Honda    Red   34335.546875    4.0   $5,000.00
# 2  Toyota   Blue   12714.453125    3.0   $7,000.00
# 3     BMW  Black    4366.796875    5.0  $22,000.00
# 4  Nissan  White   83240.234375    NaN   $3,500.00
# 5  Toyota   Blue   38755.078125    4.0   $4,500.00
# 6   Honda   Blue   17850.781250    4.0          NaN
# 7   Honda   Blue   21382.031250    4.0   $7,000.00
# 8  Toyota  White   31511.024306    4.0   $6,250.00
# 9  Nissan  White   12343.750000    4.0   $9,700.00
