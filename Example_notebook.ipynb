# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# This cell add sum

# %%
1+1
# Out:
# 2

# %%
1*0.1
# Out:
# 0.1

# %%
import pandas as pd
import numpy as np
import sklearn

# %%
df=pd.read_csv("sample_data.csv")

# %%
df.head()
# Out:
#   Month  Sales  Profit
# 0   Jan    120      30
# 1   Feb    150      45
# 2   Mar    170      50
# 3   Apr    160      48
# 4   May    180      55

# %%
df.Profit.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Profit'>

# %% [markdown]
# ![](6-step-ml-framework.png)

# %%
import matplotlib.pyplot as plt
